# %% [markdown]
# # Bank Marketing Campaign Analysis
#
# **Goal:** Explore a bank marketing dataset and build a simple model to predict whether a customer will subscribe to a term deposit (`deposit`).

# %% [markdown]
# ## 1-Import Required Libraries
# Run this cell to import required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## 2-Load the Dataset

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/JayasreeMeda/BankMarketingAnalysis/refs/heads/main/bank.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# ## 3-Dataset Overview
#
# In this section, we will:
# - Check dataset size (rows, columns)
# - View column names
# - Understand data types

# %%
## TODO:

# %%
## TODO:

# %%
## TODO:

# %% [markdown]
# ## 4-Summary Statistics
#
# We will look at numerical summary statistics to understand distributions and ranges.

# %%
## TODO:

# %% [markdown]
# ## 5-Data Cleaning Checks
#
# We will check for:
# - Missing values
# - Duplicate rows

# %%
## TODO:

# %%
## TODO:

# %% [markdown]
# ## 6-Target Distribution
#
# We will visualize how many customers subscribed (`yes`) vs not subscribed (`no`).

# %%
## TODO:

# %% [markdown]
# ## 7-Age Distribution
#
# We will plot a histogram of customer ages.

# %%
## TODO:

# %% [markdown]
# ## 8-Balance Distribution
#
# We will plot a histogram of customer balances to observe skewness/outliers.

# %%
## TODO:

# %% [markdown]
# ## 9-Deposit YES % by Job
# In this step, we analyze how the deposit subscription rate changes across different job categories.
#
# We calculate the percentage of customers who subscribed to a deposit (`yes`) for each job type.
# This helps us understand which occupations are more likely to subscribe to a term deposit.

# %%
## TODO:

# %% [markdown]
# ## 10-Feature Engineering
#
# We will create simple new features:
# - `has_any_loan`: 1 if housing loan OR personal loan is "yes", else 0
# - `balance_positive`: 1 if balance > 0, else 0

# %%
## TODO:

# %%
## TODO:

# %% [markdown]
# ## 11-Encode the Target
#
# Convert `deposit` into numbers:
# - yes → 1
# - no → 0

# %%
## TODO:

# %% [markdown]
# ## 12-Split Features and Target
#
# We separate:
# - `X` = all input features
# - `y` = target (`deposit_num`)

# %%
## TODO:

# %% [markdown]
# ## 13-Convert Text Columns to Numbers
#
# Machine learning models need numeric data.
# We convert categorical columns into numeric columns.

# %%
## TODO:

# %% [markdown]
# ## 14-Train-Test Split
#
# Split the data into:
# - Training set (to train the model)
# - Testing set (to evaluate the model)

# %%
## TODO:

# %%
## TODO:

# %% [markdown]
# ## 15-Train Logistic Regression Model
#
# We train a Logistic Regression model to predict deposit subscription.

# %%
## TODO:

# %% [markdown]
# ## 16-Model Evaluation
#
# We will:
# - Predict on test data
# - Print accuracy
# - View confusion matrix
# - Print classification report

# %%
## TODO:

# %%
## TODO:

# %%
## TODO:

# %%
## TODO:
